# %%
import numpy as np
import pandas as pd
import datetime
import csv

# %%
case_level_full_data = {}

# %%
full_charge_data = pd.read_excel('../data/steps/Step5Output_joined.xlsx')
full_charge_data.head()
# Out:
#                     arresting_pd  case_id charge_filing_date  charge_id  \
# 0  MIDDLETOWN POLICE DEPARTMENT   7422794         2001-08-04    3909041
# 1    TIVERTON POLICE DEPARTMENT   7423292         2001-09-25    3909791
# 2     Newport Police Department   7424561         2002-03-27    3911694
# 3     Newport Police Department   7424561         2002-03-27    3911693
# 4     Newport Police Department   7425369         2002-07-24    3913116
#
#    charge_number              disposition disposition_date        dob  \
# 0              1                      NaN              NaT 1965-10-27
# 1              1  Plea of Nolo Contendere       2001-10-18 1971-07-04
# 2              2            Dismissed 48A       2003-02-25 1983-04-28
# 3              1            Dismissed 48A       2003-02-25 1983-04-28
# 4              1  Plea of Nolo Contendere       2002-07-24 1976-03-25
#
#   first_name                           judge last_name offense_date  \
# 0      SCOTT                             NaN  DRISCOLL   2001-08-03
# 1        NED  Pirraglia (Retired), Robert K.    FISHER   2001-09-24
# 2     JOSEPH  Pirraglia (Retired), Robert K.  FERREIRA   2002-03-27
# 3     JOSEPH  Pirraglia (Retired), Robert K.  FERREIRA   2002-02-28
# 4       DION  Pirraglia (Retired), Robert K.    ARDREY   2002-07-11
#
#              offense_description           sentence  \
# 0     Larceny < 500 Person 65+\n                NaN
# 1     Larceny < 500 Person 65+\n  Criminal Sentence
# 2  FAILURE TO APPEAR FOR SUMMONS                NaN
# 3     Larceny < 500 Person 65+\n                NaN
# 4     Larceny < 500 Person 65+\n  Criminal Sentence
#
#                                  sentence_conditions sentence_date  \
# 0                                                NaN           NaT
# 1  Probation 1Y    Active: 10/18/2001; Court Cost...    2001-10-18
# 2                                                NaN           NaT
# 3                                                NaN           NaT
# 4  Credit for Time Served 10H    Active: 07/24/20...    2002-07-24
#
#                           sentence_terms  unique_identifier sup_case  \
# 0                                                   4232652      NaN
# 1                                                   4234254      NaN
# 2                                                   4650281      NaN
# 3                                                   4650281      NaN
# 4                                                   4651070      NaN
#
#          dc_case
# 0  21-2001-01905
# 1  21-2001-02507
# 2  21-2002-00802
# 3  21-2002-00802
# 4  21-2002-01767

# %%
for row in full_charge_data.iterrows():
    key = (row[1]['dc_case'], row[1]['sup_case'])
    if key not in case_level_full_data:
        case_level_full_data[key] = [row[1]]
    else:
        case_level_full_data[key].append(row[1])
# with open('unique_charges_w_sentences.csv', 'rb') as inf:
#     reader = csv.reader(inf, delimiter='|')
#     for line in reader:
#         charge_record = dict(
#             dc_case_num=line[0],
#             sup_case_num=line[1],
#             first_name=line[2],
#             last_name=line[3],
#             charge_id=line[4],
#             charge_description=line[5],
#             disposition=line[6],
#             sentence=line[7]
#         )
#         key = (charge_record['dc_case_num'], charge_record['sup_case_num'])
#         if key not in case_level_full_data:
#             case_level_full_data[key] = [charge_record]
#         else:
#             case_level_full_data[key].append(charge_record)

# %%
def is_elder(charge_record):
    elder_keywords = ('65', '60', 'elder')
    for kw in elder_keywords:
        if kw in charge_record['offense_description']:
            return True
    return False

# %%
def has_conviction(charge_record):
    disposition = charge_record['disposition']
    conviction_dispositions = (
        'nolo contendere plea to amended charge',
        'plea of nolo contendere',
        'guilty plea as charged',
        'found guilty by jury',
        'found guilty by judge',
        'guilty plea to amended charge',
        'alford plea entered'
    )
    for conviction_disposition in conviction_dispositions:
        if pd.isnull(disposition):
            return False
        if conviction_disposition in disposition.lower():
            return True
    return False

# %%
def was_dismissed(charge_record):
    disposition = charge_record['disposition']
    dismissal_dispositions = (
        'dismissed 48a',
        'dismissed 48b',
        'dismissed by judge',
        'dismissal'
    )
    for dismissal_disposition in dismissal_dispositions:
        if pd.isnull(disposition):
            return False
        if dismissal_disposition in disposition.lower():
            return True
    return False

# %%
def is_pending(charge_record):
    disposition = charge_record['disposition']
    pending_dispositions = (
        'information signed',
        'information signed/amended charge',
        'information/indictment waived',
        'charge information signed',
        'true bill signed',
        'charge information/indictment waived',
        'true bill signed/amended charge'
    )
    for pending_disposition in pending_dispositions:
        if pd.isnull(disposition):
            return False
        if pending_disposition in disposition.lower():
            return True
    return False

# %%
def is_missing(charge_record):
    disposition = charge_record['disposition']
    missing_dispositions = ('nan')
    for missing_disposition in missing_dispositions:
        if pd.isnull(disposition):
            return False
        if missing_disposition in disposition.lower():
            return True
    return False

# %%
def get_jailtime(charge_record):
    sentences = charge_record['sentence']
    if 'term to serve' in sentences.lower():
        sentence_array = sentences.split('   ')
        for sentence in sentence_array:
            if 'term to serve' in sentence.lower():
                string_term_to_serve = sentence.split(' ')[-1]
                if string_term_to_serve[-1].lower() == 'y':
                    return 365*int(string_term_to_serve[:1])
                elif string_term_to_serve[-1].lower() == 'm':
                    return 12*int(string_term_to_serve[:1])
                elif string_term_to_serve[-1].lower() == 'd':
                    return int(string_term_to_serve[:1])
                else:
                    raise ValueError
    return 0

# %%
def has_sentence(charge_record):
    if charge_record['sentence']:
        return True
    return False

# %%
crim_charge = pd.read_excel("../data/inputs/ChargeReport12_04_2017.xlsx")
crim_charge.head()
# Out:
#    Case ID        Case No  Charge ID  Charge Number  \
# 0  7403240   12-1990-0271    3886180              1
# 1  7403240   12-1990-0271    3886181              1
# 2  7413463  21-1994-03664    3896710              1
# 3  7422050  21-2001-01044    3907943              1
# 4  7422569  21-2001-01639    3908725              1
#
#               Offense Description Offense Date Charge Filing Date  \
# 0            ASSLT PERSON OVER 60   1990-02-22         1990-02-23
# 1  MALICIOUS DESTRUCTION PROPERTY   1990-02-22                NaT
# 2     LARCENY UNDER $500/DOMESTIC   1994-12-13         1994-12-14
# 3   Simple Assault and/or Battery   2001-04-18         2001-05-10
# 4     LARCENY UNDER $500/DOMESTIC   2001-06-27         2001-07-12
#
#                     Arresting PD
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3  PORTSMOUTH POLICE DEPARTMENT
# 4  PORTSMOUTH POLICE DEPARTMENT

# %%
case_date_map = {}
for row in crim_charge.iterrows():
    case_date_map[row[1]['Case No']] = row[1]['Charge Filing Date']

# %%
count_charged = 0
count_convicted = 0
count_sentenced = 0
count_pending = 0
count_jailed = 0
count_dismissed = 0
count_missing = 0
count_mixed = 0
jailtimes = []
pending_case_years = [0]*18
for key in case_level_full_data:
    charge_records = case_level_full_data[key]
    elder_records = [charge_record for charge_record in charge_records if is_elder(charge_record)]
    if not elder_records:
        raise ValueError
    count_charged += 1
    if any(has_conviction(charge) for charge in elder_records):
        count_convicted += 1
        if any(has_sentence(charge) for charge in elder_records):
            count_sentenced += 1
            for charge in elder_records:
                jailtime_days = get_jailtime(charge)
                if jailtime_days:
                    jailtimes.append(jailtime_days)
                    count_jailed += 1
                    continue
    elif all(was_dismissed(charge) for charge in elder_records):
        count_dismissed += 1
    elif all(is_pending(charge) for charge in elder_records):
        count_pending += 1
    elif all(is_missing(charge) for charge in elder_records):
        count_missing += 1
    else:
        count_mixed += 1

jailtimes.sort()
print(pending_case_years)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-b3c57ae6d7d5> in <module>()
#      20             count_sentenced += 1
#      21             for charge in elder_records:
# ---> 22                 jailtime_days = get_jailtime(charge)
#      23                 if jailtime_days:
#      24                     jailtimes.append(jailtime_days)
#
# <ipython-input-26-dd5a72084a7f> in get_jailtime(charge_record)
#       1 def get_jailtime(charge_record):
#       2     sentences = charge_record['sentence']
# ----> 3     if 'term to serve' in sentences.lower():
#       4         sentence_array = sentences.split('   ')
#       5         for sentence in sentence_array:
#
# AttributeError: 'float' object has no attribute 'lower'

# %%
print '{} people charged '.format(count_charged)
print '{} of those were convicted'.format(count_convicted)
print '    {} of those were sentenced'.format(count_sentenced)
print '    {} of those were jailed'.format(count_jailed)
print '{} of the total {} had every charge against them dismissed'.format(count_dismissed, count_charged)
print '{} of the total {} have every charge against them pending'.format(count_pending, count_charged)
print '{} of the total {} have one charge against them pending, one dismissed'.format(count_mixed_pending, count_charged)
print '{} of the total {} are missing dispositions in our data'.format(count_missing, count_charged)
print '{} is the sum of all of those'.format(count_convicted + count_dismissed + count_missing + count_pending)
print 'The everage jailtime was {} days, although {}/{} jailed cases were for a year or less'.format(
    sum(jailtimes)/len(jailtimes), len([k for k in jailtimes if int(k) <= 365]) ,count_jailed
)
print total_missing_sentenced
print total_pending_sentenced
print total_dismissed_sentenced
# Out:
# 1082 people charged
# 311 of those were convicted
#     309 of those were sentenced
#     139 of those were jailed
# 49 of the total 1082 had every charge against them dismissed
# 373 of the total 1082 have every charge against them pending
# 1 of the total 1082 have one charge against them pending, one dismissed
# 348 of the total 1082 are missing dispositions in our data
# 1081 is the sum of all of those
# The everage jailtime was 371 days, although 107/139 jailed cases were for a year or less
# 13
# 0
# 0

# %%
print case_level_full_data
# Out:
# {('42-2010-00805', 'W2-2010-0219A'): [{'first_name': 'KEVIN', 'last_name': 'CHAMBERLAIN', 'dc_case_num': '42-2010-00805', 'disposition': 'Information Signed', 'sentence': '', 'charge_id': '4386282', 'sup_case_num': 'W2-2010-0219A', 'charge_description': 'resisting arrest'}, {'first_name': 'KEVIN', 'last_name': 'CHAMBERLAIN', 'dc_case_num': '42-2010-00805', 'disposition': 'Information Signed/Amended Charge', 'sentence': '', 'charge_id': '4386281', 'sup_case_num': 'W2-2010-0219A', 'charge_description': 'serious injury/person >60/dom'}, {'first_name': 'KEVIN', 'last_name': 'CHAMBERLAIN', 'dc_case_num': '42-2010-00805', 'disposition': 'Information Signed', 'sentence': '', 'charge_id': '4386283', 'sup_case_num': 'W2-2010-0219A', 'charge_description': 'simple assault/domestic'}], ('42-2007-02299', ''): [{'first_name': 'EINO', 'last_name': 'WIITALA', 'dc_case_num': '42-2007-02299', 'disposition': 'Dismissed/Remand To District Court', 'sentence': '', 'charge_id': '4382212', 'sup_case_num': '', 'charge_description': 'driving with suspended license'}, {'first_name': 'EINO', 'last_name': 'WIITALA', 'dc_case_num': '42-2007-02299', 'disposition': 'No Information Signed', 'sentence': '', 'charge_id': '4382211', 'sup_case_num': '', 'charge_description': 'serious injury/person >60/dom'}], ('62-2009-04582', 'P1-2009-2055A'): [{'first_name': 'CRYSTAL', 'last_name': 'GIGUERE', 'dc_case_num': '62-2009-04582', 'disposition': 'Dismissed 48A', 'sentence': '', 'charge_id': '5085012', 'sup_case_num': 'P1-2009-2055A', 'charge_description': 'assault on person over 60'}, {'first_name': 'CRYSTAL', 'last_name': 'GIGUERE', 'dc_case_num': '62-2009-04582', 'disposition': 'True Bill Signed', 'sentence': '', 'charge_id': '5085011', 'sup_case_num': 'P1-2009-2055A', 'charge_description': 'first degree robbery'}], ('32-2017-06402', ''): [{'first_name': 'ANTHONY', 'last_name': 'CIRESI', 'dc_case_num': '32-2017-06402', 'disposition': 'nan', 'sentence': '', 'charge_id': '6144205', 'sup_case_num': '', 'charge_description': 'domestic violence - assault person > 60 causing bodily injury - 1st offense'}, {'first_name': 'ANTHONY', 'last_name': 'CIRESI', 'dc_case_num': '32-2017-06402', 'disposition': 'nan', 'sentence': '', 'charge_id': '6144206', 'sup_case_num': '', 'charge_description': 'domestic violence - disorderly conduct - 1st offense'}, {'first_name': 'ANTHONY', 'last_name': 'CIRESI', 'dc_case_num': '32-2017-06402', 'disposition': 'nan', 'sentence': '', 'charge_id': '6144205', 'sup_case_num': '', 'charge_description': 'domestic violence - assault person > 60 causing bodily injury - 1st offense'}, {'first_name': 'ANTHONY', 'last_name': 'CIRESI', 'dc_case_num': '32-2017-06402', 'disposition': 'nan', 'sentence': '', 'charge_id': '6144206', 'sup_case_num': '', 'charge_description': 'domestic violence - disorderly conduct - 1st offense'}], ('32-2017-04230', ''): [{'first_name': 'David', 'last_name': 'Graziano', 'dc_case_num': '32-2017-04230', 'disposition': 'No Information Signed', 'sentence': '', 'charge_id': '6099821', 'sup_case_num': '', 'charge_description': 'assault on person > 60 causing bodily injury'}, {'first_name': 'David', 'last_name': 'Graziano', 'dc_case_num': '32-2017-04230', 'disposition': 'No Information Signed', 'sentence': '', 'charge_id': '6099823', 'sup_case_num': '', 'charge_description': 'disorderly conduct'}, {'first_name': 'David', 'last_name': 'Graziano', 'dc_case_num': '32-2017-04230', 'disposition': 'No Information Signed', 'sentence': '', 'charge_id': '6099822', 'sup_case_num': '', 'charge_description': 'domestic violence - disorderly conduct - 1st offense'}, {'first_name': 'David', 'last_name': 'Graziano', 'dc_case_num': '32-2017-04230', 'disposition': 'No Information Signed', 'sentence': '', 'charge_id': '6099824', 'sup_case_num': '', 'charge_description': 'resisting legal or illegal arrest'}], ('32-2015-01554', 'P1-2015-1346A'): [{'first_name': 'RICHARD', 'last_name': 'HULTGREN', 'dc_case_num': '32-2015-01554', 'disposition': 'True Bill Sig ...
